# %%
import obspy
from obspy import read, UTCDateTime

# %%
t1 = UTCDateTime(2025, 1, 20, 16, 17, 26)
t2 = UTCDateTime(2025, 1, 20, 16, 17, 56)
st = read("0121Dapu.mseed")
st_slice = st.slice(t1 + 8, t1 + 13)

# %%
for i in st[129:]:
    station = i.stats.station
    if i.stats.channel == "HLZ":
        print(station)
        i.plot(outfile = "./Output/Fullwaveform/" + station + ".png")
# Out:
# SPT
# SSD
# SSH
# STY
# TAI
# TAI1
# TAW
# TCU
# TIPB
# TIPB
# TTN
# WCH1
# WDG
# WDL
# WGK
# WLC
# WNT
# WPL
# WSF
# WTC
# WTP
# WWC
# WYL
# YUS

# %%
st_slice = st.slice(t1 + 13, t1 + 20)
for i in st_slice[129:]:
    station = i.stats.station
    if i.stats.channel == "HLZ":
        print(station)
        i.plot()
# Out:
# SPT
# SSD
# SSH
# STY
# TAI
# TAI1
# TAW
# TCU
# TIPB
# TIPB
# TTN
# WCH1
# WDG
# WDL
# WGK
# WLC
# WNT
# WPL
# WSF
# WTC
# WTP
# WWC
# WYL
# YUS
